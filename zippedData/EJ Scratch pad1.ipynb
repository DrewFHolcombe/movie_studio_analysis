# %%
# Import standard packages
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
ls
# Out:
# EJ Scratch pad1.ipynb    im.db.zip                tmdb.movies.csv.gz
# bom.movie_gross.csv.gz   rt.movie_info.tsv.gz     tn.movie_budgets.csv.gz
# im.db                    rt.reviews.tsv.gz

# %%
pwd
# Out:
# '/Users/admin/Flatiron2/movie_studio_analysis/zippedData'

# %% [markdown]
# # BOM_MOVIE_GROSS DATASET

# %%
bom_movie_gross = pd.read_csv("bom.movie_gross.csv.gz")
bom_movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
#noticed NaN values in foreign_gross

bom_movie_gross.tail(30)
# Out:
#                                                   title      studio  \
# 3357                                   I Am Not a Witch          FM
# 3358                               Racer & the Jailbird       Super
# 3359                                              Rodin       Cohen
# 3360                               What Will People Say          KL
# 3361                                          A Ciambra         IFC
# 3362                                   Oolong Courtyard          CL
# 3363                                 Girls vs Gangsters       WGUSA
# 3364                              No Date, No Signature    Distrib.
# 3365                              The Apparition (2018)        MBox
# 3366                                        The Charmer          FM
# 3367                      Elliot: The Littlest Reindeer       Scre.
# 3368                                       The Workshop      Strand
# 3369                                       Loving Pablo        Uni.
# 3370                                  A Paris Education          KL
# 3371                          Tag Along: The Devil Fish          CL
# 3372                           Gabriel and the Mountain      Strand
# 3373                  Marlina the Murderer in Four Acts       Icar.
# 3374                                         The Escape         IFC
# 3375  How Victor 'The Garlic' Took Alexey 'The Stud'...     CARUSEL
# 3376        Lou Andreas-Salomé, the Audacity to be Free         CLS
# 3377                                    Let Yourself Go        Men.
# 3378                                      Hannah (2018)         PDF
# 3379                                           Souvenir      Strand
# 3380                       Furious (Legend of Kolovrat)     CARUSEL
# 3381                                Beauty and the Dogs       Osci.
# 3382                                          The Quake       Magn.
# 3383                        Edward II (2018 re-release)          FM
# 3384                                           El Pacto        Sony
# 3385                                           The Swan  Synergetic
# 3386                                  An Actor Prepares       Grav.
#
#       domestic_gross foreign_gross  year
# 3357         50900.0           NaN  2018
# 3358         46300.0           NaN  2018
# 3359         44300.0           NaN  2018
# 3360         44200.0           NaN  2018
# 3361         41900.0           NaN  2018
# 3362         37700.0           NaN  2018
# 3363         37100.0           NaN  2018
# 3364         36400.0           NaN  2018
# 3365         28300.0           NaN  2018
# 3366         26200.0           NaN  2018
# 3367         24300.0           NaN  2018
# 3368         22100.0           NaN  2018
# 3369         22000.0           NaN  2018
# 3370         21600.0           NaN  2018
# 3371         20700.0           NaN  2018
# 3372         18400.0           NaN  2018
# 3373         17800.0           NaN  2018
# 3374         14000.0           NaN  2018
# 3375         13000.0           NaN  2018
# 3376         12900.0           NaN  2018
# 3377         12200.0           NaN  2018
# 3378         11700.0           NaN  2018
# 3379         11400.0           NaN  2018
# 3380         10000.0           NaN  2018
# 3381          8900.0           NaN  2018
# 3382          6200.0           NaN  2018
# 3383          4800.0           NaN  2018
# 3384          2500.0           NaN  2018
# 3385          2400.0           NaN  2018
# 3386          1700.0           NaN  2018

# %%
bom_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom_movie_gross.loc[:,['foreign_gross']].head(11)
# Out:
#    foreign_gross
# 0      652000000
# 1      691300000
# 2      664300000
# 3      535700000
# 4      513900000
# 5      398000000
# 6      311500000
# 7      391000000
# 8      291600000
# 9      277300000
# 10     330000000

# %%
# Dropped Nan values

bom_movie_gross.dropna(subset=['foreign_gross'], axis=0, inplace=True)

# %%
#Checked NaN values removed 

bom_movie_gross['foreign_gross'].isna().sum()
# Out:
# 0

# %%
bom_movie_gross.sort_values(by=['title','domestic_gross','foreign_gross']).head(30)
# Out:
#                                           title  studio  domestic_gross  \
# 2093                                        '71   RAtt.       1300000.0
# 2395                        10 Cloverfield Lane    Par.      72100000.0
# 3222                                102 Not Out    Sony       1300000.0
# 533                                    11-11-11  Rocket         32800.0
# 3161                                  12 Strong      WB      45800000.0
# 1170                           12 Years a Slave    FoxS      56700000.0
# 93                                    127 Hours    FoxS      18300000.0
# 486                                13 Assassins   Magn.        803000.0
# 2418  13 Hours: The Secret Soldiers of Benghazi    Par.      52900000.0
# 1681                                  14 Blades    RTWC             NaN
# 1041                                   17 Girls  Strand         15100.0
# 970                          2 Days in New York   Magn.        633000.0
# 1183                                     2 Guns    Uni.      75600000.0
# 1715                       20,000 Days on Earth   Drft.        280000.0
# 765                              21 Jump Street    Sony     138400000.0
# 1236                                21 and Over   Rela.      25700000.0
# 1268                                 22 Bullets   Cdgm.             NaN
# 1502                             22 Jump Street    Sony     191700000.0
# 568                                    3 (2011)  Strand         60000.0
# 1578                             3 Days to Kill   Rela.      30700000.0
# 2990                              3 Generations   Wein.        156000.0
# 444                          30 Minutes or Less    Sony      37100000.0
# 1501                     300: Rise of An Empire      WB     106600000.0
# 969                                         360   Magn.        100000.0
# 278                               44 Inch Chest   Imag.         39000.0
# 1178                                   47 Ronin    Uni.      38400000.0
# 448                                       50/50    Sum.      35000000.0
# 2975           6 Below: Miracle on the Mountain     MOM         14800.0
# 1368                                    6 Souls    RTWC             NaN
# 1780                                    7 Boxes     BGP         38100.0
#
#      foreign_gross  year
# 2093        355000  2015
# 2395      38100000  2016
# 3222      10900000  2018
# 533        5700000  2011
# 3161      21600000  2018
# 1170     131100000  2013
# 93        42400000  2010
# 486       16800000  2011
# 2418      16600000  2016
# 1681       3800000  2014
# 1041        186000  2012
# 970        1000000  2012
# 1183      56300000  2013
# 1715       1800000  2014
# 765       63100000  2012
# 1236      22400000  2013
# 1268      21300000  2013
# 1502     139600000  2014
# 568        2600000  2011
# 1578      21900000  2014
# 2990        375000  2017
# 444        3500000  2011
# 1501     231000000  2014
# 969        1600000  2012
# 278         255000  2010
# 1178     113400000  2013
# 448        4200000  2011
# 2975       1100000  2017
# 1368        852000  2013
# 1780        267000  2014

# %%
bom_movie_gross.loc[bom_movie_gross['year'] > 2010]
# Out:
#                                                   title        studio  \
# 328         Harry Potter and the Deathly Hallows Part 2            WB
# 329                      Transformers: Dark of the Moon          P/DW
# 330         Pirates of the Caribbean: On Stranger Tides            BV
# 331             The Twilight Saga: Breaking Dawn Part 1          Sum.
# 332                Mission: Impossible - Ghost Protocol          Par.
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross foreign_gross  year
# 328      381000000.0     960500000  2011
# 329      352400000.0     771400000  2011
# 330      241100000.0     804600000  2011
# 331      281300000.0     430900000  2011
# 332      209400000.0     485300000  2011
# ...              ...           ...   ...
# 3275          1400.0       1500000  2018
# 3286        725000.0        229000  2018
# 3309         10000.0        256000  2018
# 3342         93200.0          5200  2018
# 3353         43200.0         30000  2018
#
# [1723 rows x 5 columns]

# %%
bom_movie_gross.sort_values('foreign_gross', inplace=True, ascending=False)
bom_movie_gross.iloc[0:20]
# Out:
#                                            title     studio  domestic_gross  \
# 1805                             Life's a Breeze      Magn.          3500.0
# 1331                                    The East       FoxS       2300000.0
# 302                                   White Lion      Scre.             NaN
# 2906                            A United Kingdom       FoxS       3900000.0
# 510                                     Le Havre       Jan.        612000.0
# 1546                          Heaven is for Real       TriS      91400000.0
# 155   Sea Rex 3D: Journey to a Prehistoric World         3D       6100000.0
# 3225                                The Bookshop  Greenwich       1600000.0
# 1291                           Only God Forgives       RTWC        779000.0
# 3181                           Holmes and Watson       Sony      30600000.0
# 2100                           Maps to the Stars        FCW        351000.0
# 1940            Devil and Angel (E Gun Tian Shi)         CL        131000.0
# 3120                  Disney's Christopher Robin         BV      99200000.0
# 3119                                    Creed II        MGM     115700000.0
# 135                                       Splice         WB      17000000.0
# 2808                                    The Post        Fox      81900000.0
# 2371                The Girl on the Train (2016)       Uni.      75400000.0
# 774                         Underworld Awakening       SGem      62300000.0
# 366                                    War Horse         BV      79900000.0
# 276                        The Girl on the Train     Strand        208000.0
#
#      foreign_gross  year
# 1805         99700  2014
# 1331         99700  2013
# 302          99600  2010
# 2906       9900000  2017
# 510        9900000  2011
# 1546       9900000  2014
# 155        9900000  2010
# 3225       9900000  2018
# 1291       9900000  2013
# 3181       9900000  2018
# 2100        988000  2015
# 1940      98500000  2015
# 3120      98500000  2018
# 3119      98300000  2018
# 135        9800000  2010
# 2808      97900000  2017
# 2371      97800000  2016
# 774       97800000  2012
# 366       97700000  2011
# 276          97100  2010

# %%
bom_movie_gross.tail(30)
# Out:
#                                        title     studio  domestic_gross  \
# 1917                       The Hateful Eight      Wein.      54100000.0
# 37                                 Yogi Bear         WB     100200000.0
# 1158                         American Hustle       Sony     150100000.0
# 2810                  The Hitman's Bodyguard       LG/S      75500000.0
# 382                         Arthur Christmas       Sony      46500000.0
# 1649                      Gladiators of Rome        VPD          8200.0
# 894                           Rec 3: Genesis      Magn.          9600.0
# 272                         Formosa Betrayed      Scre.        225000.0
# 2358                     Ghostbusters (2016)       Sony     128400000.0
# 63            Aftershock (Tangshan Dadizhen)         CL         63000.0
# 3124                 Insidious: The Last Key       Uni.      67700000.0
# 40                                The A-Team        Fox      77200000.0
# 1256                                Nebraska       Par.      17700000.0
# 3218                    The Sisters Brothers  Annapurna       3100000.0
# 506           Snow Flower and the Secret Fan       FoxS       1300000.0
# 2032                          Kung Fu Killer      WGUSA        130000.0
# 989             Once Upon a Time in Anatolia       CGld        152000.0
# 2427                Barbershop: The Next Cut    WB (NL)      54000000.0
# 2539                                Desierto        STX       2000000.0
# 596                    The Time That Remains        IFC         32900.0
# 955                          Kid With a Bike        IFC       1500000.0
# 594                  Vanishing on 7th Street      Magn.         22700.0
# 2859  Tyler Perry's Boo 2! A Madea Halloween        LGF      47300000.0
# 970                       2 Days in New York      Magn.        633000.0
# 3009                          City of Ghosts        IFC        128000.0
# 3079                  Avengers: Infinity War         BV     678800000.0
# 1874                               Furious 7       Uni.     353000000.0
# 1872            Star Wars: The Force Awakens         BV     936700000.0
# 1873                          Jurassic World       Uni.     652300000.0
# 2760                 The Fate of the Furious       Uni.     226000000.0
#
#      foreign_gross  year
# 1917     101600000  2015
# 37       101300000  2010
# 1158     101100000  2013
# 2810     101100000  2017
# 382      101000000  2011
# 1649      10100000  2014
# 894       10100000  2012
# 272         101000  2010
# 2358     100800000  2016
# 63       100200000  2010
# 3124     100100000  2018
# 40       100000000  2010
# 1256      10000000  2013
# 3218      10000000  2018
# 506       10000000  2011
# 2032      10000000  2015
# 989        1000000  2012
# 2427       1000000  2016
# 2539       1000000  2016
# 596        1000000  2011
# 955        1000000  2012
# 594        1000000  2011
# 2859       1000000  2017
# 970        1000000  2012
# 3009        100000  2017
# 3079       1,369.5  2018
# 1874       1,163.0  2015
# 1872       1,131.6  2015
# 1873       1,019.4  2015
# 2760       1,010.0  2017

# %%
bom_movie_gross.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %% [markdown]
# # MOVIE_INFO DATASET

# %%
movie_info = pd.read_csv("./rt.movie_info.tsv.gz", sep="\t")
movie_info
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
movie_info.columns
# Out:
# Index(['id', 'synopsis', 'rating', 'genre', 'director', 'writer',
#        'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime',
#        'studio'],
#       dtype='object')

# %%
movie_info.loc[:,['genre','currency','box_office']].head(20)
# Out:
#                                                 genre currency  box_office
# 0                 Action and Adventure|Classics|Drama      NaN         NaN
# 1                   Drama|Science Fiction and Fantasy        $     600,000
# 2                   Drama|Musical and Performing Arts      NaN         NaN
# 3                          Drama|Mystery and Suspense      NaN         NaN
# 4                                       Drama|Romance      NaN         NaN
# 5                               Drama|Kids and Family      NaN         NaN
# 6                                              Comedy        $  41,032,915
# 7                                               Drama        $     224,114
# 8                                               Drama        $     134,904
# 9   Action and Adventure|Mystery and Suspense|Scie...      NaN         NaN
# 10                                                NaN      NaN         NaN
# 11                                        Documentary      NaN         NaN
# 12                       Documentary|Special Interest      NaN         NaN
# 13                              Classics|Comedy|Drama      NaN         NaN
# 14                                             Comedy      NaN         NaN
# 15                  Comedy|Drama|Mystery and Suspense        $   1,039,869
# 16                                              Drama        $  99,165,609
# 17                  Action and Adventure|Comedy|Drama      NaN         NaN
# 18  Action and Adventure|Drama|Science Fiction and...        $  20,518,224
# 19  Art House and International|Comedy|Drama|Music...        $   1,971,135

# %%
import pandas as pd

# %%
def clean_money(df, money_column):
    df[money_column] = df[money_column].str.replace(',','')
    df[money_column] = df[money_column].str.replace('$','')
    df[money_column] = pd.to_numeric(df[money_column])
    return df

# %%
movie_budgets = pd.read_csv("tn.movie_budgets.csv.gz")
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
movie_budgets = clean_money(movie_budgets,'production_budget')
movie_budgets = clean_money(movie_budgets,'domestic_gross')
movie_budgets = clean_money(movie_budgets,'worldwide_gross')

# %%
movie_budgets.loc[:,['movie','production_budget','domestic_gross','worldwide_gross']].head(20)
# Out:
#                                           movie  production_budget  \
# 0                                        Avatar          425000000
# 1   Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                  Dark Phoenix          350000000
# 3                       Avengers: Age of Ultron          330600000
# 4             Star Wars Ep. VIII: The Last Jedi          317000000
# 5          Star Wars Ep. VII: The Force Awakens          306000000
# 6                        Avengers: Infinity War          300000000
# 7    Pirates of the Caribbean: At Worldâs End          300000000
# 8                                Justice League          300000000
# 9                                       Spectre          300000000
# 10                        The Dark Knight Rises          275000000
# 11                      Solo: A Star Wars Story          275000000
# 12                              The Lone Ranger          275000000
# 13                                  John Carter          275000000
# 14                                      Tangled          260000000
# 15                                 Spider-Man 3          258000000
# 16                   Captain America: Civil War          250000000
# 17           Batman v Superman: Dawn of Justice          250000000
# 18            The Hobbit: An Unexpected Journey          250000000
# 19       Harry Potter and the Half-Blood Prince          250000000
#
#     domestic_gross  worldwide_gross
# 0        760507625       2776345279
# 1        241063875       1045663875
# 2         42762350        149762350
# 3        459005868       1403013963
# 4        620181382       1316721747
# 5        936662225       2053311220
# 6        678815482       2048134200
# 7        309420425        963420425
# 8        229024295        655945209
# 9        200074175        879620923
# 10       448139099       1084439099
# 11       213767512        393151347
# 12        89302115        260002115
# 13        73058679        282778100
# 14       200821936        586477240
# 15       336530303        894860230
# 16       408084349       1140069413
# 17       330360194        867500281
# 18       303003568       1017003568
# 19       302089278        935213767

# %%
movie_budgets['ROI_worldwide_gross'] = movie_budgets['worldwide_gross'] / movie_budgets['production_budget']-1
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  ROI_worldwide_gross
# 0             425000000       760507625       2776345279             5.532577
# 1             410600000       241063875       1045663875             1.546673
# 2             350000000        42762350        149762350            -0.572108
# 3             330600000       459005868       1403013963             3.243841
# 4             317000000       620181382       1316721747             3.153696
# ...                 ...             ...              ...                  ...
# 5777               7000               0                0            -1.000000
# 5778               6000           48482           240495            39.082500
# 5779               5000            1338             1338            -0.732400
# 5780               1400               0                0            -1.000000
# 5781               1100          181041           181041           163.582727
#
# [5782 rows x 7 columns]

# %%
movie_budgets.iloc[100:110]
# Out:
#      id  release_date                                  movie  \
# 100   1  May 29, 2009                                     Up
# 101   2  Nov 22, 2017                                   Coco
# 102   3  Nov 21, 2018              Ralph Breaks The Internet
# 103   4  Mar 27, 2009                    Monsters vs. Aliens
# 104   5  Jun 16, 2017                                 Cars 3
# 105   6   Aug 7, 2009            G.I. Joe: The Rise of Cobra
# 106   7  Jun 30, 1999                         Wild Wild West
# 107   8   Aug 1, 2008  The Mummy: Tomb of the Dragon Emperor
# 108   9  Jun 22, 2007                          Evan Almighty
# 109  10  Jul 28, 1995                             Waterworld
#
#      production_budget  domestic_gross  worldwide_gross  ROI_worldwide_gross
# 100          175000000       293004164        731463377             3.179791
# 101          175000000       209726015        798008101             3.560046
# 102          175000000       201091711        524283695             1.995907
# 103          175000000       198351526        381687380             1.181071
# 104          175000000       152901115        383541369             1.191665
# 105          175000000       150201498        302469017             0.728394
# 106          175000000       113805681        221229335             0.264168
# 107          175000000       102491776        405760225             1.318630
# 108          175000000       100289690        174131329            -0.004964
# 109          175000000        88246220        264246220             0.509978

# %%
movie_budgets['ROI'] = movie_budgets['domestic_gross'] / movie_budgets['production_budget']-1
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  ROI_worldwide_gross  \
# 0             425000000       760507625       2776345279             5.532577
# 1             410600000       241063875       1045663875             1.546673
# 2             350000000        42762350        149762350            -0.572108
# 3             330600000       459005868       1403013963             3.243841
# 4             317000000       620181382       1316721747             3.153696
# ...                 ...             ...              ...                  ...
# 5777               7000               0                0            -1.000000
# 5778               6000           48482           240495            39.082500
# 5779               5000            1338             1338            -0.732400
# 5780               1400               0                0            -1.000000
# 5781               1100          181041           181041           163.582727
#
#              ROI
# 0       0.789430
# 1      -0.412899
# 2      -0.877822
# 3       0.388403
# 4       0.956408
# ...          ...
# 5777   -1.000000
# 5778    7.080333
# 5779   -0.732400
# 5780   -1.000000
# 5781  163.582727
#
# [5782 rows x 8 columns]

# %%
movie_budgets['ROI_domestic'] = movie_budgets['domestic_gross'] / movie_budgets['production_budget']-1
movie_budgets.drop(labels=['ROI'],axis=1)
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  ROI_worldwide_gross  \
# 0             425000000       760507625       2776345279             5.532577
# 1             410600000       241063875       1045663875             1.546673
# 2             350000000        42762350        149762350            -0.572108
# 3             330600000       459005868       1403013963             3.243841
# 4             317000000       620181382       1316721747             3.153696
# ...                 ...             ...              ...                  ...
# 5777               7000               0                0            -1.000000
# 5778               6000           48482           240495            39.082500
# 5779               5000            1338             1338            -0.732400
# 5780               1400               0                0            -1.000000
# 5781               1100          181041           181041           163.582727
#
#       ROI_domestic
# 0         0.789430
# 1        -0.412899
# 2        -0.877822
# 3         0.388403
# 4         0.956408
# ...            ...
# 5777     -1.000000
# 5778      7.080333
# 5779     -0.732400
# 5780     -1.000000
# 5781    163.582727
#
# [5782 rows x 8 columns]

# %%
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  ROI_worldwide_gross  \
# 0             425000000       760507625       2776345279             5.532577
# 1             410600000       241063875       1045663875             1.546673
# 2             350000000        42762350        149762350            -0.572108
# 3             330600000       459005868       1403013963             3.243841
# 4             317000000       620181382       1316721747             3.153696
# ...                 ...             ...              ...                  ...
# 5777               7000               0                0            -1.000000
# 5778               6000           48482           240495            39.082500
# 5779               5000            1338             1338            -0.732400
# 5780               1400               0                0            -1.000000
# 5781               1100          181041           181041           163.582727
#
#              ROI  ROI_domestic
# 0       0.789430      0.789430
# 1      -0.412899     -0.412899
# 2      -0.877822     -0.877822
# 3       0.388403      0.388403
# 4       0.956408      0.956408
# ...          ...           ...
# 5777   -1.000000     -1.000000
# 5778    7.080333      7.080333
# 5779   -0.732400     -0.732400
# 5780   -1.000000     -1.000000
# 5781  163.582727    163.582727
#
# [5782 rows x 9 columns]

# %%
fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(x=movie_budgets["production_budget"], y=movie_budgets["ROI"])

# %%
movie_budgets['worldwide_gross'].isna() .sum()
# Out:
# 0

# %%
movie_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   5782 non-null   int64
#  1   release_date         5782 non-null   object
#  2   movie                5782 non-null   object
#  3   production_budget    5782 non-null   int64
#  4   domestic_gross       5782 non-null   int64
#  5   worldwide_gross      5782 non-null   int64
#  6   ROI_worldwide_gross  5782 non-null   float64
#  7   ROI                  5782 non-null   float64
#  8   ROI_domestic         5782 non-null   float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 406.7+ KB

# %%
#bom_movie_gross.sort_values('worldwide_gross', inplace=True, ascending=False)
movie_budgets.sort_values('worldwide_gross', inplace=True, ascending=False)
movie_budgets
# Out:
#       id  release_date                                 movie  \
# 0      1  Dec 18, 2009                                Avatar
# 42    43  Dec 19, 1997                               Titanic
# 5      6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 6      7  Apr 27, 2018                Avengers: Infinity War
# 33    34  Jun 12, 2015                        Jurassic World
# ...   ..           ...                                   ...
# 5474  75  Dec 31, 2005                       Insomnia Manica
# 5473  74  Jul 17, 2012                       Girls Gone Dead
# 5472  73   Apr 3, 2012                         Enter Nowhere
# 5471  72  Dec 31, 2010                                Drones
# 4068  69  Dec 12, 2008                The Kings of Appletown
#
#       production_budget  domestic_gross  worldwide_gross  ROI_worldwide_gross  \
# 0             425000000       760507625       2776345279             5.532577
# 42            200000000       659363944       2208208395            10.041042
# 5             306000000       936662225       2053311220             5.710167
# 6             300000000       678815482       2048134200             5.827114
# 33            215000000       652270625       1648854864             6.669092
# ...                 ...             ...              ...                  ...
# 5474             500000               0                0            -1.000000
# 5473             500000               0                0            -1.000000
# 5472             500000               0                0            -1.000000
# 5471             500000               0                0            -1.000000
# 4068            7000000               0                0            -1.000000
#
#            ROI  ROI_domestic
# 0     0.789430      0.789430
# 42    2.296820      2.296820
# 5     2.060988      2.060988
# 6     1.262718      1.262718
# 33    2.033817      2.033817
# ...        ...           ...
# 5474 -1.000000     -1.000000
# 5473 -1.000000     -1.000000
# 5472 -1.000000     -1.000000
# 5471 -1.000000     -1.000000
# 4068 -1.000000     -1.000000
#
# [5782 rows x 9 columns]

# %%
movie_budgets.sort_values('release_date', inplace=True, ascending=False)
movie_budgets
# Out:
#       id release_date                     movie  production_budget  \
# 3129  30  Sep 9, 2016  The Disappointments Room           15000000
# 849   50  Sep 9, 2016                     Sully           60000000
# 3287  88  Sep 9, 2016           Robinson Crusoe           13000000
# 3712  13  Sep 9, 2016                     Kicks           10000000
# 3584  85  Sep 9, 2016     When the Bough Breaks           10000000
# ...   ..          ...                       ...                ...
# 1408   9  Apr 1, 2005                  Sin City           40000000
# 5769  70  Apr 1, 1996                      Bang              10000
# 2260  61  Apr 1, 1988   Bright Lights, Big City           25000000
# 5520  21  Apr 1, 1986   My Beautiful Laundrette             400000
# 5559  60  Apr 1, 1975           Death Race 2000             300000
#
#       domestic_gross  worldwide_gross  ROI_worldwide_gross       ROI  \
# 3129         2423467          3503761            -0.766416 -0.838436
# 849        125070033        238524556             2.975409  1.084501
# 3287         8005586         42446455             2.265112 -0.384186
# 3712          150191           150191            -0.984981 -0.984981
# 3584        29747603         30768449             2.076845  1.974760
# ...              ...              ...                  ...       ...
# 1408        74103820        158527918             2.963198  0.852596
# 5769             527              527            -0.947300 -0.947300
# 2260        16118077         16118077            -0.355277 -0.355277
# 5520               0                0            -1.000000 -1.000000
# 5559               0                0            -1.000000 -1.000000
#
#       ROI_domestic
# 3129     -0.838436
# 849       1.084501
# 3287     -0.384186
# 3712     -0.984981
# 3584      1.974760
# ...            ...
# 1408      0.852596
# 5769     -0.947300
# 2260     -0.355277
# 5520     -1.000000
# 5559     -1.000000
#
# [5782 rows x 9 columns]

# %%
import sqlite3

# %%
con = sqlite3.connect("./im.db")
cursor = con.cursor()

# %%
schema_df = pd.read_sql("""
SELECT *
FROM sqlite_master
""", con)
schema_df
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
movie_basics = pd.read_sql("""

SELECT *
FROM movie_basics
""", con).drop_duplicates(subset = ['movie_id'])

# %%
movie_basics = movie_basics.drop_duplicates(subset = ['primary_title','original_title','start_year'])
movie_basics.duplicated(subset = ['primary_title','original_title','start_year']).sum()
# Out:
# 0

# %%
movie_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [144563 rows x 6 columns]

# %%
movie_basics['primary_title'] = movie_basics['primary_title'].str.lower()
movie_basics['primary_title'] = movie_basics['primary_title'].replace([':','\.','\,',"'",'!'], '', regex = True)

# %%
movie_budgets
# Out:
#       id release_date                     movie  production_budget  \
# 3129  30  Sep 9, 2016  The Disappointments Room           15000000
# 849   50  Sep 9, 2016                     Sully           60000000
# 3287  88  Sep 9, 2016           Robinson Crusoe           13000000
# 3712  13  Sep 9, 2016                     Kicks           10000000
# 3584  85  Sep 9, 2016     When the Bough Breaks           10000000
# ...   ..          ...                       ...                ...
# 1408   9  Apr 1, 2005                  Sin City           40000000
# 5769  70  Apr 1, 1996                      Bang              10000
# 2260  61  Apr 1, 1988   Bright Lights, Big City           25000000
# 5520  21  Apr 1, 1986   My Beautiful Laundrette             400000
# 5559  60  Apr 1, 1975           Death Race 2000             300000
#
#       domestic_gross  worldwide_gross  ROI_worldwide_gross       ROI  \
# 3129         2423467          3503761            -0.766416 -0.838436
# 849        125070033        238524556             2.975409  1.084501
# 3287         8005586         42446455             2.265112 -0.384186
# 3712          150191           150191            -0.984981 -0.984981
# 3584        29747603         30768449             2.076845  1.974760
# ...              ...              ...                  ...       ...
# 1408        74103820        158527918             2.963198  0.852596
# 5769             527              527            -0.947300 -0.947300
# 2260        16118077         16118077            -0.355277 -0.355277
# 5520               0                0            -1.000000 -1.000000
# 5559               0                0            -1.000000 -1.000000
#
#       ROI_domestic
# 3129     -0.838436
# 849       1.084501
# 3287     -0.384186
# 3712     -0.984981
# 3584      1.974760
# ...            ...
# 1408      0.852596
# 5769     -0.947300
# 2260     -0.355277
# 5520     -1.000000
# 5559     -1.000000
#
# [5782 rows x 9 columns]

# %%
movie_basics = pd.read_sql("""
SELECT *
FROM movie_basics



""",con)

# %%
merge_ds = movie_budgets.merge(movie_basics,left_on='movie',right_on='primary_title',how='inner')
merge_ds
# Out:
#       id release_date                     movie  production_budget  \
# 0     30  Sep 9, 2016  The Disappointments Room           15000000
# 1     50  Sep 9, 2016                     Sully           60000000
# 2     13  Sep 9, 2016                     Kicks           10000000
# 3     85  Sep 9, 2016     When the Bough Breaks           10000000
# 4     85  Sep 9, 2016     When the Bough Breaks           10000000
# ...   ..          ...                       ...                ...
# 3810  41  Apr 1, 2011        The Last Godfather           13400000
# 3811  34  Apr 1, 2011                     Super            2500000
# 3812  34  Apr 1, 2011                     Super            2500000
# 3813  34  Apr 1, 2011                     Super            2500000
# 3814  70  Apr 1, 1996                      Bang              10000
#
#       domestic_gross  worldwide_gross  ROI_worldwide_gross       ROI  \
# 0            2423467          3503761            -0.766416 -0.838436
# 1          125070033        238524556             2.975409  1.084501
# 2             150191           150191            -0.984981 -0.984981
# 3           29747603         30768449             2.076845  1.974760
# 4           29747603         30768449             2.076845  1.974760
# ...              ...              ...                  ...       ...
# 3810          164247           164247            -0.987743 -0.987743
# 3811          327716           593933            -0.762427 -0.868914
# 3812          327716           593933            -0.762427 -0.868914
# 3813          327716           593933            -0.762427 -0.868914
# 3814             527              527            -0.947300 -0.947300
#
#       ROI_domestic   movie_id             primary_title  \
# 0        -0.838436  tt2364897  The Disappointments Room
# 1         1.084501  tt3263904                     Sully
# 2        -0.984981  tt4254584                     Kicks
# 3         1.974760  tt1389139     When the Bough Breaks
# 4         1.974760  tt6814096     When the Bough Breaks
# ...            ...        ...                       ...
# 3810     -0.987743  tt1584131        The Last Godfather
# 3811     -0.868914  tt1512235                     Super
# 3812     -0.868914  tt1807022                     Super
# 3813     -0.868914  tt7456902                     Super
# 3814     -0.947300  tt6616538                      Bang
#
#                 original_title  start_year  runtime_minutes  \
# 0     The Disappointments Room        2016             85.0
# 1                        Sully        2016             96.0
# 2                        Kicks        2016             80.0
# 3        When the Bough Breaks        2016            107.0
# 4        When the Bough Breaks        2017             93.0
# ...                        ...         ...              ...
# 3810        The Last Godfather        2010            100.0
# 3811                     Super        2010             96.0
# 3812                     Super        2010            140.0
# 3813                     Super        2016             92.0
# 3814                      Bang        2015              NaN
#
#                      genres
# 0     Drama,Horror,Thriller
# 1           Biography,Drama
# 2           Adventure,Drama
# 3        Crime,Drama,Horror
# 4                      None
# ...                     ...
# 3810   Comedy,Crime,Romance
# 3811    Action,Comedy,Drama
# 3812                  Drama
# 3813              Adventure
# 3814                   None
#
# [3815 rows x 15 columns]

# %%
merge_ds = movie_budgets.merge(movie_basics,left_on='movie',right_on='primary_title',how='inner')

merge_ds['profit'] = merge_ds['worldwide_gross'] - merge_ds['production_budget']
merge_ds['ROI'] = merge_ds['profit'] / merge_ds['production_budget']
merge_ds['Profit Margin'] = merge_ds['profit'] / merge_ds['worldwide_gross'] * 100

# %%
#deleting col to start narrowing down data to view value

deleted_columns = ['id', 'movie_id', 'primary_title', 'original_title', 
                  'start_year', 'runtime_minutes']
merge_ds.drop(columns=deleted_columns, inplace=True)

# %%
#data frame with deleted columns
merge_ds
# Out:
#      release_date                     movie  production_budget  \
# 0     Sep 9, 2016  The Disappointments Room           15000000
# 1     Sep 9, 2016                     Sully           60000000
# 2     Sep 9, 2016                     Kicks           10000000
# 3     Sep 9, 2016     When the Bough Breaks           10000000
# 4     Sep 9, 2016     When the Bough Breaks           10000000
# ...           ...                       ...                ...
# 3810  Apr 1, 2011        The Last Godfather           13400000
# 3811  Apr 1, 2011                     Super            2500000
# 3812  Apr 1, 2011                     Super            2500000
# 3813  Apr 1, 2011                     Super            2500000
# 3814  Apr 1, 1996                      Bang              10000
#
#       domestic_gross  worldwide_gross  ROI_worldwide_gross       ROI  \
# 0            2423467          3503761            -0.766416 -0.766416
# 1          125070033        238524556             2.975409  2.975409
# 2             150191           150191            -0.984981 -0.984981
# 3           29747603         30768449             2.076845  2.076845
# 4           29747603         30768449             2.076845  2.076845
# ...              ...              ...                  ...       ...
# 3810          164247           164247            -0.987743 -0.987743
# 3811          327716           593933            -0.762427 -0.762427
# 3812          327716           593933            -0.762427 -0.762427
# 3813          327716           593933            -0.762427 -0.762427
# 3814             527              527            -0.947300 -0.947300
#
#       ROI_domestic                 genres     profit  Profit Margin
# 0        -0.838436  Drama,Horror,Thriller  -11496239    -328.111392
# 1         1.084501        Biography,Drama  178524556      74.845357
# 2        -0.984981        Adventure,Drama   -9849809   -6558.188573
# 3         1.974760     Crime,Drama,Horror   20768449      67.499174
# 4         1.974760                   None   20768449      67.499174
# ...            ...                    ...        ...            ...
# 3810     -0.987743   Comedy,Crime,Romance  -13235753   -8058.444294
# 3811     -0.868914    Action,Comedy,Drama   -1906067    -320.922899
# 3812     -0.868914                  Drama   -1906067    -320.922899
# 3813     -0.868914              Adventure   -1906067    -320.922899
# 3814     -0.947300                   None      -9473   -1797.533207
#
# [3815 rows x 11 columns]

# %%
genres_list = ['Romance','Thriller','Action','Comedy','Drama','Sci-Fi','Documentary','Animation','Fantasy','Adventure','Family','Sport','War','Horror']

genres_dict = {}
genres_dict['Genre'] = []
genres_dict['Median Profit Margin'] = []
genres_dict['Median Budget'] = []
genres_dict['Median ROI'] = []
genres_dict['Number of Films'] = []

for genre in genres_list:
    merge_ds[genre] = merge_ds['genres'].str.contains(genre)
    
    genres_dict['Genre'].append(genre)
    genres_dict['Median Profit Margin'].append(merge_ds.groupby([genre])[['Profit Margin']].agg('median').sort_values(by = 'Profit Margin', ascending = False).iloc[0][0])
    genres_dict['Median Budget'].append(merge_ds.groupby([genre])[['production_budget']].agg('median').sort_values(by = 'production_budget', ascending = False).iloc[0][0])
    genres_dict['Median ROI'].append(merge_ds.groupby([genre])[['ROI']].agg('median').sort_values(by = 'ROI', ascending = False).iloc[0][0])
    genres_dict['Number of Films'].append(merge_ds['genres'].str.contains(genre).sum() )

    
print(merge_ds['Profit Margin'].median())


genres_df = pd.DataFrame(genres_dict)
genres_df = genres_df.sort_values(by = 'Median Profit Margin', ascending = False)
display(genres_df)
# Out:
# 32.031595986485165
#           Genre  Median Profit Margin  Median Budget  Median ROI  \
# 7     Animation             64.200283       74500000    1.793318
# 9     Adventure             56.391856       73621553    1.293170
# 5        Sci-Fi             53.771616       30000000    1.163173
# 8       Fantasy             52.374319       41000000    1.099711
# 10       Family             47.181782       20000000    0.893540
# 3        Comedy             46.240603       20000000    0.860140
# 2        Action             42.278494       38000000    0.732457
# 0       Romance             40.663051       17000000    0.685858
# 4         Drama             39.343254       20000000    0.648640
# 6   Documentary             33.758716       17250000    0.509634
# 13       Horror             33.409874       18000000    0.501724
# 1      Thriller             33.263067       16000000    0.498421
# 11        Sport             32.555317       16000000    0.482697
# 12          War             32.314491       16000000    0.477421
#
#     Number of Films
# 7               148
# 9               490
# 5               229
# 8               202
# 10              204
# 3               842
# 2               710
# 0               372
# 4              1817
# 6               499
# 13              415
# 1               594
# 11               75
# 12               53

# %%
genres_df.describe()
# Out:
#        Median Profit Margin  Median Budget  Median ROI  Number of Films
# count             14.000000   1.400000e+01   14.000000        14.000000
# mean              43.410480   2.981225e+07    0.831422       475.000000
# std               10.277437   2.043970e+07    0.388254       453.494805
# min               32.314491   1.600000e+07    0.477421        53.000000
# 25%               33.497084   1.706250e+07    0.503702       202.500000
# 50%               41.470773   2.000000e+07    0.709157       393.500000
# 75%               51.076185   3.600000e+07    1.048168       570.250000
# max               64.200283   7.450000e+07    1.793318      1817.000000

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
 
genres_df = sns.load_dataset("genres_df")
g = sns.jointplot(x="total_bill", y="tip", data=tips,
                  kind="reg", truncate=False,
                  xlim=(0, 60), ylim=(0, 12),
                  color="m", height=7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-1d39b1b9891e> in <module>
#       2 sns.set_theme(style="darkgrid")
#       3
# ----> 4 genres_df = sns.load_dataset("genres_df")
#       5 g = sns.jointplot(x="total_bill", y="tip", data=tips,
#       6                   kind="reg", truncate=False,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     484         if not os.path.exists(cache_path):
#     485             if name not in get_dataset_names():
# --> 486                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     487             urlretrieve(full_path, cache_path)
#     488         full_path = cache_path
#
# ValueError: 'genres_df' is not one of the example datasets.
